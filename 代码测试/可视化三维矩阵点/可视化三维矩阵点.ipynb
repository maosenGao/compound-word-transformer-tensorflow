# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation
x = np.arange(0,10,0.5)
y = np.arange(0,10,0.5)
z = np.arange(0,10,0.5)

x,y,z = np.meshgrid(x,y,z)

color = np.array([i+j+k for i,j,k in zip(x,y,z)])
print(color*10)
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(x,y,z,c=color)
# plt.savefig('1.png',dpi=100)

#旋转三维图并且保存成gif格式
def update(i):
    label = 'timestep {0}'.format(i)

    # 更新直线和x轴（用一个新的x轴的标签）。
    # 用元组（Tuple）的形式返回在这一帧要被重新绘图的物体
    horiAngle = (45 + 3 * i)%360#transition(i, 40)
    vertAngle = (45 + 3 * i)%360#transition(i, 40)
    print(label,horiAngle,vertAngle)
    ax.view_init(vertAngle, horiAngle)
    filename = str('%03d' % i) + '.png'
    plt.savefig(filename, dpi=96)
    return ax
anim = FuncAnimation(fig, update, frames=np.arange(0, 120), interval=200)
anim.save('line.gif', dpi=120, writer='imagemagick')
# Out:
# [[[  0.   5.  10. ...  85.  90.  95.]
#   [  5.  10.  15. ...  90.  95. 100.]
#   [ 10.  15.  20. ...  95. 100. 105.]
#   ...
#   [ 85.  90.  95. ... 170. 175. 180.]
#   [ 90.  95. 100. ... 175. 180. 185.]
#   [ 95. 100. 105. ... 180. 185. 190.]]
#
#  [[  5.  10.  15. ...  90.  95. 100.]
#   [ 10.  15.  20. ...  95. 100. 105.]
#   [ 15.  20.  25. ... 100. 105. 110.]
#   ...
#   [ 90.  95. 100. ... 175. 180. 185.]
#   [ 95. 100. 105. ... 180. 185. 190.]
#   [100. 105. 110. ... 185. 190. 195.]]
#
#  [[ 10.  15.  20. ...  95. 100. 105.]
#   [ 15.  20.  25. ... 100. 105. 110.]
#   [ 20.  25.  30. ... 105. 110. 115.]
#   ...
#   [ 95. 100. 105. ... 180. 185. 190.]
#   [100. 105. 110. ... 185. 190. 195.]
#   [105. 110. 115. ... 190. 195. 200.]]
#
#  ...
#
#  [[ 85.  90.  95. ... 170. 175. 180.]
#   [ 90.  95. 100. ... 175. 180. 185.]
#   [ 95. 100. 105. ... 180. 185. 190.]
#   ...
#   [170. 175. 180. ... 255. 260. 265.]
#   [175. 180. 185. ... 260. 265. 270.]
#   [180. 185. 190. ... 265. 270. 275.]]
#
#  [[ 90.  95. 100. ... 175. 180. 185.]
#   [ 95. 100. 105. ... 180. 185. 190.]
#   [100. 105. 110. ... 185. 190. 195.]
#   ...
#   [175. 180. 185. ... 260. 265. 270.]
#   [180. 185. 190. ... 265. 270. 275.]
#   [185. 190. 195. ... 270. 275. 280.]]
#
#  [[ 95. 100. 105. ... 180. 185. 190.]
#   [100. 105. 110. ... 185. 190. 195.]
#   [105. 110. 115. ... 190. 195. 200.]
#   ...
#   [180. 185. 190. ... 265. 270. 275.]
#   [185. 190. 195. ... 270. 275. 280.]
#   [190. 195. 200. ... 275. 280. 285.]]]
# timestep 0 45 45
# timestep 0 45 45
# timestep 1 48 48
# timestep 2 51 51
# timestep 3 54 54
# timestep 4 57 57
# timestep 5 60 60
# timestep 6 63 63
# timestep 7 66 66
# timestep 8 69 69
# timestep 9 72 72
# timestep 10 75 75
# timestep 11 78 78
# timestep 12 81 81
# timestep 13 84 84
# timestep 14 87 87
# timestep 15 90 90
# timestep 16 93 93
# timestep 17 96 96
# timestep 18 99 99
# timestep 19 102 102
# timestep 20 105 105
# timestep 21 108 108
# timestep 22 111 111
# timestep 23 114 114
# timestep 24 117 117
# timestep 25 120 120
# timestep 26 123 123
# timestep 27 126 126
# timestep 28 129 129
# timestep 29 132 132
# timestep 30 135 135
# timestep 31 138 138
# timestep 32 141 141
# timestep 33 144 144
# timestep 34 147 147
# timestep 35 150 150
# timestep 36 153 153
# timestep 37 156 156
# timestep 38 159 159
# timestep 39 162 162
# timestep 40 165 165
# timestep 41 168 168
# timestep 42 171 171
# timestep 43 174 174
# timestep 44 177 177
# timestep 45 180 180
# timestep 46 183 183
# timestep 47 186 186
# timestep 48 189 189
# timestep 49 192 192
# timestep 50 195 195
# timestep 51 198 198
# timestep 52 201 201
# timestep 53 204 204
# timestep 54 207 207
# timestep 55 210 210
# timestep 56 213 213
# timestep 57 216 216
# timestep 58 219 219
# timestep 59 222 222
# timestep 60 225 225
# timestep 61 228 228
# timestep 62 231 231
# timestep 63 234 234
# timestep 64 237 237
# timestep 65 240 240
# timestep 66 243 243
# timestep 67 246 246
# timestep 68 249 249
# timestep 69 252 252
# timestep 70 255 255
# timestep 71 258 258
# timestep 72 261 261
# timestep 73 264 264
# timestep 74 267 267
# timestep 75 270 270
# timestep 76 273 273
# timestep 77 276 276
# timestep 78 279 279
# timestep 79 282 282
# timestep 80 285 285
# timestep 81 288 288
# timestep 82 291 291
# timestep 83 294 294
# timestep 84 297 297
# timestep 85 300 300
# timestep 86 303 303
# timestep 87 306 306
# timestep 88 309 309
# timestep 89 312 312
# timestep 90 315 315
# timestep 91 318 318
# timestep 92 321 321
# timestep 93 324 324
# timestep 94 327 327
# timestep 95 330 330
# timestep 96 333 333
# timestep 97 336 336
# timestep 98 339 339
# timestep 99 342 342
# timestep 100 345 345
# timestep 101 348 348
